# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import torch

# %%
torch.__version__
# Out:
# '2.13.0+cpu'
